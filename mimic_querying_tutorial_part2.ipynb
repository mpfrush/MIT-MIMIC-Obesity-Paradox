# %% [markdown]
# ## MIMIC-III Querying Tutorial
#
# [Tutorial is available online](https://mimic.physionet.org/tutorials/intro-to-mimic-iii/)
#
# Dr. Maria P. Frushicheva @ MIT

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2

# used to calculate AUROC/accuracy
from sklearn import metrics

# %matplotlib inline

# %%
# create a database connection
sqluser = 'mimic' 
dbname = 'mimic'
schema_name = 'mimiciii'

# Connect to local postgres version of mimic
con = psycopg2.connect(dbname=dbname, user=sqluser)
cur = con.cursor()

# %% [markdown]
#  ### Counting the Number of Patients in the Database

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
select count(subject_id)
from mimiciii.patients;
"""
data = pd.read_sql_query(query,con)
data
# Out:
#    count
# 0  46520

# %% [markdown]
# ### Database Metadata for the Admissions Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM admissions;
"""
data = pd.read_sql_query(query,con)
data.head()
# Out:
#    row_id  subject_id  hadm_id           admittime           dischtime  \
# 0      90          87   190659 2191-02-25 20:30:00 2191-04-25 15:18:00
# 1      91          88   123010 2111-08-29 03:03:00 2111-09-03 14:24:00
# 2      92          89   188646 2185-06-17 05:22:00 2185-06-21 11:15:00
# 3      93          91   121205 2177-04-23 00:08:00 2177-05-10 15:16:00
# 4      94          92   142807 2122-12-13 19:30:00 2123-03-04 13:47:00
#
#              deathtime admission_type         admission_location  \
# 0                 None        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 1                 None      EMERGENCY       EMERGENCY ROOM ADMIT
# 2                 None        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 3  2177-05-10 15:16:00      EMERGENCY       EMERGENCY ROOM ADMIT
# 4                 None        NEWBORN  PHYS REFERRAL/NORMAL DELI
#
#     discharge_location insurance language      religion marital_status  \
# 0  SHORT TERM HOSPITAL   Private           UNOBTAINABLE
# 1                 HOME   Private
# 2  SHORT TERM HOSPITAL  Medicaid           UNOBTAINABLE
# 3         DEAD/EXPIRED  Medicare                 JEWISH        MARRIED
# 4  SHORT TERM HOSPITAL  Medicaid           UNOBTAINABLE
#
#                 ethnicity           edregtime           edouttime  \
# 0   UNKNOWN/NOT SPECIFIED                 NaT                 NaT
# 1  BLACK/AFRICAN AMERICAN 2111-08-29 01:44:00 2111-08-29 02:28:00
# 2   UNKNOWN/NOT SPECIFIED                 NaT                 NaT
# 3                   WHITE 2177-04-22 21:02:00 2177-04-23 04:03:00
# 4                   WHITE                 NaT                 NaT
#
#                              diagnosis  hospital_expire_flag  \
# 0                              NEWBORN                     0
# 1  S/P MOTOR VEHICLE ACCIDENT-STABBING                     0
# 2                              NEWBORN                     0
# 3                                FEVER                     1
# 4                              NEWBORN                     0
#
#    has_ioevents_data  has_chartevents_data
# 0                  1                     1
# 1                  1                     1
# 2                  1                     1
# 3                  1                     1
# 4                  1                     1

# %% [markdown]
# ### Database Metadata for the Patients Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM patients;
"""
data = pd.read_sql_query(query,con)
data.head()
# Out:
#    row_id  subject_id gender        dob                  dod dod_hosp  \
# 0     612         646      M 2128-01-05                 None     None
# 1     613         647      M 2106-03-24                 None     None
# 2     614         648      M 2139-07-13                 None     None
# 3     615         649      M 2177-06-23                 None     None
# 4     616         650      M 2051-04-15  2111-12-28 00:00:00     None
#
#                dod_ssn  expire_flag
# 0                 None            0
# 1                 None            0
# 2                 None            0
# 3                 None            0
# 4  2111-12-28 00:00:00            1

# %% [markdown]
# ### Database Metadata for the CharteventsTable

# %%
## Too long to execute!!!
#cur.execute('SET search_path to ' + schema_name)
#query = \
#"""
#SELECT *
#FROM chartevents;
#"""
#data = pd.read_sql_query(query,con)
#data.head()

# %% [markdown]
#  ### The Number of Patients in the Patients Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT COUNT(*)
FROM patients;
"""
data = pd.read_sql_query(query,con)
data
# Out:
#    count
# 0  46520

# %% [markdown]
# ### The Distinct Values of Gender

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT DISTINCT(gender)
FROM patients;
"""
data = pd.read_sql_query(query,con)
data
# Out:
#   gender
# 0      M
# 1      F

# %% [markdown]
# ### The Number of Female Patients

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT COUNT(*)
FROM patients
WHERE gender = 'F';
"""
data = pd.read_sql_query(query,con)
data
# Out:
#    count
# 0  20399

# %% [markdown]
# ### The Numbers of Male and Female Patients

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT gender, COUNT(*)
FROM patients
GROUP BY gender;
"""
data = pd.read_sql_query(query,con)
data
# Out:
#   gender  count
# 0      M  26121
# 1      F  20399

# %% [markdown]
# ### Count the Number of Patients Who Died in the Hospital

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT expire_flag, COUNT(*)
FROM patients
GROUP BY expire_flag;
"""
data = pd.read_sql_query(query,con)
data
# Out:
#    expire_flag  count
# 0            0  30761
# 1            1  15759

# %% [markdown]
# ### Patient Age and Mortality

# %% [markdown]
# Combine the patients and admissions tables to find patient admission dates and dates of birth. We have denoted ‘admissions’ with the alias ‘a’ and ‘patients’ with alias ‘p’.

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT p.subject_id, p.dob, a.hadm_id,
    a.admittime, p.expire_flag
FROM admissions a
INNER JOIN patients p
ON p.subject_id = a.subject_id;
"""
data = pd.read_sql_query(query,con)
data.shape
# Out:
# (58976, 5)

# %% [markdown]
#  The earliest admission time for each patient.

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT p.subject_id, p.dob, a.hadm_id,
    a.admittime, p.expire_flag,
    MIN (a.admittime) OVER (PARTITION BY p.subject_id) AS first_admittime
FROM admissions a
INNER JOIN patients p
ON p.subject_id = a.subject_id
ORDER BY a.hadm_id, p.subject_id;
"""
data = pd.read_sql_query(query,con)
data.head()
# Out:
#    subject_id        dob  hadm_id           admittime  expire_flag  \
# 0       58526 2082-03-21   100001 2117-09-11 11:46:00            0
# 1       54610 2090-05-19   100003 2150-04-17 15:34:00            1
# 2        9895 2059-05-07   100006 2108-04-06 15:49:00            1
# 3       23018 2071-06-04   100007 2145-03-31 05:33:00            0
# 4         533 2101-07-30   100009 2162-05-16 15:56:00            0
#
#       first_admittime
# 0 2117-09-11 11:46:00
# 1 2150-04-17 15:34:00
# 2 2108-04-06 15:49:00
# 3 2145-03-31 05:33:00
# 4 2162-05-16 15:56:00

# %% [markdown]
# A patient’s age is given by the difference between their date of birth and the date of their first admission.

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
WITH first_admission_time AS
(
  SELECT
      p.subject_id, p.dob, p.gender
      , MIN (a.admittime) AS first_admittime
      , MIN( ROUND( (cast(admittime as date) - cast(dob as date)) / 365.242,2) )
          AS first_admit_age
  FROM patients p
  INNER JOIN admissions a
  ON p.subject_id = a.subject_id
  GROUP BY p.subject_id, p.dob, p.gender
  ORDER BY p.subject_id
)
SELECT
    subject_id, dob, gender
    , first_admittime, first_admit_age
    , CASE
        -- all ages > 89 in the database were replaced with 300
        WHEN first_admit_age > 89
            then '>89'
        WHEN first_admit_age >= 14
            THEN 'adult'
        WHEN first_admit_age <= 1
            THEN 'neonate'
        ELSE 'middle'
        END AS age_group
FROM first_admission_time
ORDER BY subject_id
"""
data = pd.read_sql_query(query,con)
data.head()
# Out:
#    subject_id        dob gender     first_admittime  first_admit_age age_group
# 0           2 2138-07-17      M 2138-07-17 19:04:00             0.00   neonate
# 1           3 2025-04-11      M 2101-10-20 19:08:00            76.52     adult
# 2           4 2143-05-12      F 2191-03-16 00:28:00            47.84     adult
# 3           5 2103-02-02      M 2103-02-02 04:31:00             0.00   neonate
# 4           6 2109-06-21      F 2175-05-30 07:15:00            65.94     adult

# %% [markdown]
# ### The number of adult patients, whether or not they died, and therefore, their mortality rate.

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
WITH first_admission_time AS
(
  SELECT
      p.subject_id, p.dob, p.gender
      , MIN (a.admittime) AS first_admittime
      , MIN( ROUND( (cast(admittime as date) - cast(dob as date)) / 365.242,2) )
          AS first_admit_age
  FROM patients p
  INNER JOIN admissions a
  ON p.subject_id = a.subject_id
  GROUP BY p.subject_id, p.dob, p.gender
  ORDER BY p.subject_id
)
, age as
(
  SELECT
      subject_id, dob, gender
      , first_admittime, first_admit_age
      , CASE
          -- all ages > 89 in the database were replaced with 300
          -- we check using > 100 as a conservative threshold to ensure we capture all these patients
          WHEN first_admit_age > 100
              then '>89'
          WHEN first_admit_age >= 14
              THEN 'adult'
          WHEN first_admit_age <= 1
              THEN 'neonate'
          ELSE 'middle'
          END AS age_group
  FROM first_admission_time
)
select age_group, gender
  , count(subject_id) as NumberOfPatients
from age
group by age_group, gender
"""
data = pd.read_sql_query(query,con)
data
# Out:
#   age_group gender  numberofpatients
# 0     adult      M             21179
# 1   neonate      F              3629
# 2       >89      M               697
# 3     adult      F             15476
# 4   neonate      M              4245
# 5       >89      F              1294

# %% [markdown]
# ### ICU Stays: Patient ICU movements are recorded in the Transfers table.
#
# Entries that have nothing in both previous and current careunit columns indicate that the patient has been transfered between non intensive care units.

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM transfers;
"""
data = pd.read_sql_query(query,con)
print data.shape
data
# Out:
# (261897, 13)
#         row_id  subject_id  hadm_id  icustay_id    dbsource  eventtype  \
# 0          141          32   175413         NaN     carevue   transfer
# 1          142          32   175413         NaN     carevue  discharge
# 2          143          33   176176    296681.0     carevue      admit
# 3          144          33   176176         NaN     carevue   transfer
# 4          145          33   176176         NaN     carevue  discharge
# 5          146          34   115799         NaN     carevue      admit
# 6          147          34   115799    263086.0     carevue   transfer
# 7          148          34   115799         NaN     carevue   transfer
# 8          149          34   115799         NaN     carevue  discharge
# 9          150          34   144319    290505.0  metavision      admit
# 10         151          34   144319         NaN  metavision   transfer
# 11         152          34   144319    290505.0  metavision   transfer
# 12         153          34   144319         NaN  metavision   transfer
# 13         154          34   144319         NaN  metavision  discharge
# 14         155          35   166707         NaN     carevue      admit
# 15         156          35   166707    282039.0     carevue   transfer
# 16         157          35   166707         NaN     carevue   transfer
# 17         158          35   166707         NaN     carevue   transfer
# 18         159          35   166707         NaN     carevue  discharge
# 19         160          36   182104         NaN     carevue      admit
# 20         161          36   182104         NaN     carevue   transfer
# 21         162          36   182104    280987.0     carevue   transfer
# 22         163          36   182104         NaN     carevue   transfer
# 23         164          36   182104         NaN     carevue  discharge
# 24         165          36   122659         NaN     carevue      admit
# 25         166          36   122659    211200.0     carevue   transfer
# 26         167          36   122659    211200.0     carevue   transfer
# 27         168          36   122659    211200.0     carevue   transfer
# 28         169          36   122659         NaN     carevue   transfer
# 29         170          36   122659         NaN     carevue  discharge
# ...        ...         ...      ...         ...         ...        ...
# 261867  257580       96865   179015         NaN  metavision   transfer
# 261868  257581       96865   179015    219388.0  metavision   transfer
# 261869  257582       96865   179015         NaN  metavision   transfer
# 261870  257583       96865   179015         NaN  metavision   transfer
# 261871  257584       96865   179015         NaN  metavision  discharge
# 261872  257585       96869   130094         NaN  metavision      admit
# 261873  257586       96869   130094    266220.0  metavision   transfer
# 261874  257587       96869   130094         NaN  metavision   transfer
# 261875  257588       96869   130094         NaN  metavision   transfer
# 261876  257589       96869   130094         NaN  metavision  discharge
# 261877  257590       96872   145225    297807.0  metavision      admit
# 261878  257591       96872   145225    297807.0  metavision   transfer
# 261879  257592       96872   145225         NaN  metavision   transfer
# 261880  257593       96872   145225         NaN  metavision  discharge
# 261881  257594       96873   159095         NaN  metavision      admit
# 261882  257595       96873   159095    296132.0  metavision   transfer
# 261883  257596       96873   159095         NaN  metavision   transfer
# 261884  257597       96873   159095         NaN  metavision   transfer
# 261885  257598       96873   159095         NaN  metavision  discharge
# 261886  257599       96877   130213    258306.0  metavision      admit
# 261887  257600       96877   130213         NaN  metavision   transfer
# 261888  257601       96877   130213         NaN  metavision  discharge
# 261889  257602       96879   181282         NaN  metavision      admit
# 261890  257603       96879   181282    288154.0  metavision   transfer
# 261891  257604       96879   181282         NaN  metavision  discharge
# 261892  257605       96881   153877         NaN  metavision      admit
# 261893  257606       96881   153877    261085.0  metavision   transfer
# 261894  257607       96881   153877    261085.0  metavision   transfer
# 261895  257608       96881   153877         NaN  metavision   transfer
# 261896  257609       96881   153877         NaN  metavision  discharge
#
#        prev_careunit curr_careunit  prev_wardid  curr_wardid  \
# 0                                           7.0          2.0
# 1                                           2.0          NaN
# 2                             MICU          NaN         12.0
# 3               MICU                       12.0         45.0
# 4                                          45.0          NaN
# 5                                           NaN         17.0
# 6                             MICU         17.0         23.0
# 7               MICU                       23.0          2.0
# 8                                           2.0          NaN
# 9                              CCU          NaN          7.0
# 10               CCU                        7.0         32.0
# 11                             CCU         32.0          7.0
# 12               CCU                        7.0         17.0
# 13                                         17.0          NaN
# 14                                          NaN         27.0
# 15                            CSRU         27.0         15.0
# 16              CSRU                       15.0         55.0
# 17                                         55.0         55.0
# 18                                         55.0          NaN
# 19                                          NaN         17.0
# 20                                         17.0         49.0
# 21                            CSRU         49.0         12.0
# 22              CSRU                       12.0         55.0
# 23                                         55.0          NaN
# 24                                          NaN         55.0
# 25                            CSRU         55.0         15.0
# 26              CSRU          CSRU         15.0         15.0
# 27              CSRU          CSRU         15.0         15.0
# 28              CSRU                       15.0         55.0
# 29                                         55.0          NaN
# ...              ...           ...          ...          ...
# 261867                                     32.0         18.0
# 261868                        MICU         18.0         52.0
# 261869          MICU                       52.0         18.0
# 261870                                     18.0         18.0
# 261871                                     18.0          NaN
# 261872                                      NaN         18.0
# 261873                        MICU         18.0         23.0
# 261874          MICU                       23.0         28.0
# 261875                                     28.0         48.0
# 261876                                     48.0          NaN
# 261877                        CSRU          NaN         15.0
# 261878          CSRU          CSRU         15.0         15.0
# 261879          CSRU                       15.0          3.0
# 261880                                      3.0          NaN
# 261881                                      NaN         28.0
# 261882                        MICU         28.0         52.0
# 261883          MICU                       52.0         28.0
# 261884                                     28.0         28.0
# 261885                                     28.0          NaN
# 261886                       TSICU          NaN         14.0
# 261887         TSICU                       14.0         31.0
# 261888                                     31.0          NaN
# 261889                                      NaN         17.0
# 261890                         CCU         17.0          7.0
# 261891           CCU                        7.0          NaN
# 261892                                      NaN         27.0
# 261893                        CSRU         27.0         15.0
# 261894          CSRU           CCU         15.0          7.0
# 261895           CCU                        7.0          2.0
# 261896                                      2.0          NaN
#
#                     intime             outtime     los
# 0      2170-04-15 20:21:00 2170-04-23 12:45:00  184.40
# 1      2170-04-23 12:45:00                 NaT     NaN
# 2      2116-12-23 22:31:53 2116-12-25 11:49:55   37.30
# 3      2116-12-25 11:49:55 2116-12-27 12:05:48   48.26
# 4      2116-12-27 12:05:48                 NaT     NaN
# 5      2186-07-18 16:46:43 2186-07-18 18:10:49    1.40
# 6      2186-07-18 18:10:49 2186-07-19 11:27:20   17.28
# 7      2186-07-19 11:27:20 2186-07-20 16:07:25   28.67
# 8      2186-07-20 16:07:25                 NaT     NaN
# 9      2191-02-23 05:25:32 2191-02-23 05:33:33    0.13
# 10     2191-02-23 05:33:33 2191-02-23 06:09:12    0.59
# 11     2191-02-23 06:09:12 2191-02-24 19:24:10   37.25
# 12     2191-02-24 19:24:10 2191-02-25 20:20:53   24.95
# 13     2191-02-25 20:20:53                 NaT     NaN
# 14     2122-02-10 00:25:57 2122-02-10 09:39:59    9.23
# 15     2122-02-10 09:39:59 2122-02-15 18:41:01  129.02
# 16     2122-02-15 18:41:01 2122-02-15 18:41:08    0.00
# 17     2122-02-15 18:41:08 2122-02-20 15:28:57  116.80
# 18     2122-02-20 15:28:57                 NaT     NaN
# 19     2131-04-30 16:55:36 2131-05-04 07:40:10   86.74
# 20     2131-05-04 07:40:10 2131-05-04 10:29:14    2.82
# 21     2131-05-04 10:29:14 2131-05-05 13:07:03   26.63
# 22     2131-05-05 13:07:03 2131-05-08 14:04:56   72.96
# 23     2131-05-08 14:04:56                 NaT     NaN
# 24     2131-05-12 19:51:04 2131-05-16 23:18:26   99.46
# 25     2131-05-16 23:18:26 2131-05-17 06:15:36    6.95
# 26     2131-05-17 06:15:36 2131-05-18 11:00:06   28.74
# 27     2131-05-18 11:00:06 2131-05-23 19:56:11  128.93
# 28     2131-05-23 19:56:11 2131-05-25 13:29:35   41.56
# 29     2131-05-25 13:29:35                 NaT     NaN
# ...                    ...                 ...     ...
# 261867 2135-11-20 14:11:26 2135-11-21 19:18:55   29.12
# 261868 2135-11-21 19:18:55 2135-11-22 17:14:01   21.92
# 261869 2135-11-22 17:14:01 2135-11-26 21:59:39  100.76
# 261870 2135-11-26 21:59:39 2135-11-27 15:08:00   17.14
# 261871 2135-11-27 15:08:00                 NaT     NaN
# 261872 2148-04-17 01:25:36 2148-04-17 02:36:05    1.17
# 261873 2148-04-17 02:36:05 2148-04-18 19:06:00   40.50
# 261874 2148-04-18 19:06:00 2148-04-20 14:53:52   43.80
# 261875 2148-04-20 14:53:52 2148-04-23 19:40:40   76.78
# 261876 2148-04-23 19:40:40                 NaT     NaN
# 261877 2196-02-12 20:48:06 2196-02-12 21:24:16    0.60
# 261878 2196-02-12 21:24:16 2196-02-18 13:11:22  135.79
# 261879 2196-02-18 13:11:22 2196-02-21 16:11:01   74.99
# 261880 2196-02-21 16:11:01                 NaT     NaN
# 261881 2180-12-23 22:09:21 2180-12-25 09:58:44   35.82
# 261882 2180-12-25 09:58:44 2180-12-26 16:35:25   30.61
# 261883 2180-12-26 16:35:25 2180-12-26 16:43:45    0.14
# 261884 2180-12-26 16:43:45 2181-01-01 13:13:43  140.50
# 261885 2181-01-01 13:13:43                 NaT     NaN
# 261886 2174-06-02 00:40:19 2174-06-03 15:07:31   38.45
# 261887 2174-06-03 15:07:31 2174-06-04 11:48:10   20.68
# 261888 2174-06-04 11:48:10                 NaT     NaN
# 261889 2191-07-21 11:25:37 2191-07-21 19:03:44    7.64
# 261890 2191-07-21 19:03:44 2191-07-26 18:25:32  119.36
# 261891 2191-07-26 18:25:32                 NaT     NaN
# 261892 2173-11-02 00:10:06 2173-11-02 09:45:08    9.58
# 261893 2173-11-02 09:45:08 2173-11-03 15:34:55   29.83
# 261894 2173-11-03 15:34:55 2173-11-03 15:47:16    0.21
# 261895 2173-11-03 15:47:16 2173-11-06 12:03:13   68.27
# 261896 2173-11-06 12:03:13                 NaT     NaN
#
# [261897 rows x 13 columns]

# %% [markdown]
# ### Exercise 1

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT ie.subject_id, ie.hadm_id, ie.icustay_id, ie.intime, ie.outtime
FROM icustays AS ie;
"""
data = pd.read_sql_query(query,con)
print data.shape
data.head()
# Out:
# (61532, 5)
#    subject_id  hadm_id  icustay_id              intime             outtime
# 0         109   139061      257358 2141-09-11 10:13:28 2141-09-12 16:53:07
# 1         109   172335      262652 2141-09-20 20:44:36 2141-09-22 21:44:50
# 2         109   126055      236124 2141-10-13 23:11:01 2141-10-25 20:49:04
# 3         109   125288      257134 2141-11-18 14:01:37 2141-11-19 21:35:18
# 4         109   161950      237552 2141-11-24 16:12:07 2141-11-26 21:51:50

# %% [markdown]
# ### Exercise 2: Using the Patients table retrieve the calculated age of patients.

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT ie.subject_id, ie.hadm_id, ie.icustay_id, ie.intime, ie.outtime,
    ROUND((cast(ie.intime as date) - cast(p.dob as date))/365.242, 2) AS age
FROM icustays ie
INNER JOIN patients p
ON ie.subject_id = p.subject_id;
"""
data = pd.read_sql_query(query,con)
print data.shape
data.head()
# Out:
# (61532, 6)
#    subject_id  hadm_id  icustay_id              intime             outtime  \
# 0         109   139061      257358 2141-09-11 10:13:28 2141-09-12 16:53:07
# 1         109   172335      262652 2141-09-20 20:44:36 2141-09-22 21:44:50
# 2         109   126055      236124 2141-10-13 23:11:01 2141-10-25 20:49:04
# 3         109   125288      257134 2141-11-18 14:01:37 2141-11-19 21:35:18
# 4         109   161950      237552 2141-11-24 16:12:07 2141-11-26 21:51:50
#
#      age
# 0  24.10
# 1  24.12
# 2  24.18
# 3  24.28
# 4  24.30

# %% [markdown]
# ### Exercise 3: Separate neonates from adult patients.

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
WITH first_time AS
(
SELECT ie.subject_id, ie.hadm_id, ie.icustay_id, ie.intime, ie.outtime,
    ROUND((cast(ie.intime as date) - cast(p.dob as date))/365.242, 2) AS age
FROM icustays ie
INNER JOIN patients p
ON ie.subject_id = p.subject_id
)
SELECT
    subject_id, intime, age
    , CASE
        -- all ages > 89 in the database were replaced with 300
        WHEN age > 89
            then '>89'
        WHEN age >= 14
            THEN 'adult'
        WHEN age <= 1
            THEN 'neonate'
        ELSE 'middle'
        END AS age_group
FROM first_time
ORDER BY subject_id
"""
data = pd.read_sql_query(query,con)
print data.shape
data.head()
# Out:
# (61532, 4)
#    subject_id              intime    age age_group
# 0           2 2138-07-17 21:20:07   0.00   neonate
# 1           3 2101-10-20 19:10:11  76.52     adult
# 2           4 2191-03-16 00:29:31  47.84     adult
# 3           5 2103-02-02 06:04:24   0.00   neonate
# 4           6 2175-05-30 21:30:54  65.94     adult
