# %% [markdown]
# ## Explore MIMIC-III: Overview of the MIMIC-III Data
#
# [Tutorial is available online](https://mimic.physionet.org/tutorials/intro-to-mimic-iii/)
#
# Dr. Maria P. Frushicheva @ MIT

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2

# used to calculate AUROC/accuracy
from sklearn import metrics

# %matplotlib inline

# %%
# create a database connection
sqluser = 'mimic' 
dbname = 'mimic'
schema_name = 'mimiciii'

# Connect to local postgres version of mimic
con = psycopg2.connect(dbname=dbname, user=sqluser)
cur = con.cursor()

# %% [markdown]
# ## Define and Track Patient Stays

# %% [markdown]
# ### Admissions Table (defines HADM_ID)

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM admissions;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 58976 rows and  20 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# admittime
# dischtime
# deathtime
# admission_type
# admission_location
# discharge_location
# insurance
# language
# religion
# marital_status
# ethnicity
# edregtime
# edouttime
# diagnosis
# hospital_expire_flag
# has_ioevents_data
# has_chartevents_data
#    row_id  subject_id  hadm_id           admittime           dischtime  \
# 0      90          87   190659 2191-02-25 20:30:00 2191-04-25 15:18:00
# 1      91          88   123010 2111-08-29 03:03:00 2111-09-03 14:24:00
# 2      92          89   188646 2185-06-17 05:22:00 2185-06-21 11:15:00
# 3      93          91   121205 2177-04-23 00:08:00 2177-05-10 15:16:00
# 4      94          92   142807 2122-12-13 19:30:00 2123-03-04 13:47:00
#
#              deathtime admission_type         admission_location  \
# 0                 None        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 1                 None      EMERGENCY       EMERGENCY ROOM ADMIT
# 2                 None        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 3  2177-05-10 15:16:00      EMERGENCY       EMERGENCY ROOM ADMIT
# 4                 None        NEWBORN  PHYS REFERRAL/NORMAL DELI
#
#     discharge_location insurance language      religion marital_status  \
# 0  SHORT TERM HOSPITAL   Private           UNOBTAINABLE
# 1                 HOME   Private
# 2  SHORT TERM HOSPITAL  Medicaid           UNOBTAINABLE
# 3         DEAD/EXPIRED  Medicare                 JEWISH        MARRIED
# 4  SHORT TERM HOSPITAL  Medicaid           UNOBTAINABLE
#
#                 ethnicity           edregtime           edouttime  \
# 0   UNKNOWN/NOT SPECIFIED                 NaT                 NaT
# 1  BLACK/AFRICAN AMERICAN 2111-08-29 01:44:00 2111-08-29 02:28:00
# 2   UNKNOWN/NOT SPECIFIED                 NaT                 NaT
# 3                   WHITE 2177-04-22 21:02:00 2177-04-23 04:03:00
# 4                   WHITE                 NaT                 NaT
#
#                              diagnosis  hospital_expire_flag  \
# 0                              NEWBORN                     0
# 1  S/P MOTOR VEHICLE ACCIDENT-STABBING                     0
# 2                              NEWBORN                     0
# 3                                FEVER                     1
# 4                              NEWBORN                     0
#
#    has_ioevents_data  has_chartevents_data
# 0                  1                     1
# 1                  1                     1
# 2                  1                     1
# 3                  1                     1
# 4                  1                     1

# %% [markdown]
# ### Callout Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM callout;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 34499 rows and  24 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# submit_wardid
# submit_careunit
# curr_wardid
# curr_careunit
# callout_wardid
# callout_service
# request_tele
# request_resp
# request_cdiff
# request_mrsa
# request_vre
# callout_status
# callout_outcome
# discharge_wardid
# acknowledge_status
# createtime
# updatetime
# acknowledgetime
# outcometime
# firstreservationtime
# currentreservationtime
#    row_id  subject_id  hadm_id  submit_wardid submit_careunit  curr_wardid  \
# 0      64         109   137510           23.0                         45.0
# 1      65         109   151240           14.0                         45.0
# 2      66         109   102024           50.0                         45.0
# 3      67         109   102024           23.0            MICU         23.0
# 4      68         109   102024           23.0                         45.0
#
#   curr_careunit  callout_wardid callout_service  request_tele  \
# 0          MICU               1             MED             0
# 1         TSICU              45             MED             0
# 2          MICU               1             MED             1
# 3          MICU               1             MED             0
# 4          MICU               1             MED             0
#
#            ...            callout_status  callout_outcome  discharge_wardid  \
# 0          ...                  Inactive       Discharged              45.0
# 1          ...                  Inactive       Discharged              45.0
# 2          ...                  Inactive       Discharged              45.0
# 3          ...                  Inactive        Cancelled               NaN
# 4          ...                  Inactive       Discharged              45.0
#
#    acknowledge_status          createtime          updatetime  \
# 0        Acknowledged 2142-04-21 08:39:33 2142-04-21 08:39:33
# 1        Acknowledged 2142-05-15 19:08:17 2142-05-16 08:18:02
# 2        Acknowledged 2142-05-22 07:19:54 2142-05-22 07:19:54
# 3        Acknowledged 2142-06-02 18:52:11 2142-06-03 07:53:38
# 4        Acknowledged 2142-06-03 10:57:20 2142-06-03 10:57:20
#
#       acknowledgetime         outcometime firstreservationtime  \
# 0 2142-04-21 08:43:50 2142-04-21 22:25:07  2142-04-21 18:25:10
# 1 2142-05-16 08:21:34 2142-05-16 10:55:09  2142-05-16 06:55:09
# 2 2142-05-22 08:01:04 2142-05-22 22:25:08  2142-05-22 19:40:10
# 3 2142-06-02 19:10:40 2142-06-03 07:53:38  2142-06-02 19:25:14
# 4 2142-06-03 11:30:03 2142-06-03 14:55:08  2142-06-03 11:55:08
#
#   currentreservationtime
# 0                   None
# 1                   None
# 2                   None
# 3    2142-06-03 07:40:08
# 4                   None
#
# [5 rows x 24 columns]

# %% [markdown]
# ### ICUSTAYS Table (defines ICUSTAY_ID)

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM icustays;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 61532 rows and  12 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# icustay_id
# dbsource
# first_careunit
# last_careunit
# first_wardid
# last_wardid
# intime
# outtime
# los
#    row_id  subject_id  hadm_id  icustay_id    dbsource first_careunit  \
# 0     132         109   139061      257358  metavision           MICU
# 1     133         109   172335      262652  metavision           MICU
# 2     134         109   126055      236124  metavision           MICU
# 3     135         109   125288      257134  metavision           SICU
# 4     136         109   161950      237552  metavision           MICU
#
#   last_careunit  first_wardid  last_wardid              intime  \
# 0          MICU            52           52 2141-09-11 10:13:28
# 1          MICU            23           23 2141-09-20 20:44:36
# 2          SICU            23           57 2141-10-13 23:11:01
# 3          MICU            57           50 2141-11-18 14:01:37
# 4          MICU            23           23 2141-11-24 16:12:07
#
#               outtime      los
# 0 2141-09-12 16:53:07   1.2775
# 1 2141-09-22 21:44:50   2.0418
# 2 2141-10-25 20:49:04  11.9014
# 3 2141-11-19 21:35:18   1.3151
# 4 2141-11-26 21:51:50   2.2359

# %% [markdown]
# ### Patients Table (defines SUBJECT_ID)

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM patients;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 46520 rows and  8 columns
#
# Column Names:
# row_id
# subject_id
# gender
# dob
# dod
# dod_hosp
# dod_ssn
# expire_flag
#    row_id  subject_id gender        dob                  dod dod_hosp  \
# 0     612         646      M 2128-01-05                 None     None
# 1     613         647      M 2106-03-24                 None     None
# 2     614         648      M 2139-07-13                 None     None
# 3     615         649      M 2177-06-23                 None     None
# 4     616         650      M 2051-04-15  2111-12-28 00:00:00     None
#
#                dod_ssn  expire_flag
# 0                 None            0
# 1                 None            0
# 2                 None            0
# 3                 None            0
# 4  2111-12-28 00:00:00            1

# %% [markdown]
# ### Services Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM services;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 73343 rows and  6 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# transfertime
# prev_service
# curr_service
#    row_id  subject_id  hadm_id        transfertime prev_service curr_service
# 0     312         188   132401 2162-01-10 18:27:52          MED         SURG
# 1     313         189   119333 2132-09-08 00:17:12                     CSURG
# 2     314         190   177065 2138-08-01 13:21:55                        NB
# 3     315         191   142081 2191-12-30 16:34:56                       MED
# 4     316         191   136614 2196-04-09 17:43:40                      CMED

# %% [markdown]
# ### Transfers Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM transfers;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 261897 rows and  13 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# icustay_id
# dbsource
# eventtype
# prev_careunit
# curr_careunit
# prev_wardid
# curr_wardid
# intime
# outtime
# los
#    row_id  subject_id  hadm_id  icustay_id dbsource  eventtype prev_careunit  \
# 0     141          32   175413         NaN  carevue   transfer
# 1     142          32   175413         NaN  carevue  discharge
# 2     143          33   176176    296681.0  carevue      admit
# 3     144          33   176176         NaN  carevue   transfer          MICU
# 4     145          33   176176         NaN  carevue  discharge
#
#   curr_careunit  prev_wardid  curr_wardid              intime  \
# 0                        7.0          2.0 2170-04-15 20:21:00
# 1                        2.0          NaN 2170-04-23 12:45:00
# 2          MICU          NaN         12.0 2116-12-23 22:31:53
# 3                       12.0         45.0 2116-12-25 11:49:55
# 4                       45.0          NaN 2116-12-27 12:05:48
#
#               outtime     los
# 0 2170-04-23 12:45:00  184.40
# 1                 NaT     NaN
# 2 2116-12-25 11:49:55   37.30
# 3 2116-12-27 12:05:48   48.26
# 4                 NaT     NaN

# %% [markdown]
# ## Data from Critical Care Unit

# %% [markdown]
# ### Caregivers Table (defines CGID)

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM caregivers;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 7567 rows and  4 columns
#
# Column Names:
# row_id
# cgid
# label
# description
#    row_id   cgid label            description
# 0     135  14197    SW          Social Worker
# 1     136  14198   Res  Resident/Fellow/PA/NP
# 2     137  14199    RO              Read Only
# 3     138  14200    MD              Read Only
# 4     139  14201   CRT

# %% [markdown]
# ### Chartevents Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM chartevents
LIMIT 100;
"""
data = pd.read_sql_query(query,con)

#print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Column Names:
# row_id
# subject_id
# hadm_id
# icustay_id
# itemid
# charttime
# storetime
# cgid
# value
# valuenum
# valueuom
# warning
# error
# resultstatus
# stopped
#      row_id  subject_id  hadm_id  icustay_id  itemid           charttime  \
# 0  33865841          38   185910      248910     128 2166-08-24 01:00:00
# 1  33865842          38   185910      248910     159 2166-08-24 01:00:00
# 2  33865843          38   185910      248910     160 2166-08-24 01:00:00
# 3  33865844          38   185910      248910     161 2166-08-24 01:00:00
# 4  33865845          38   185910      248910     162 2166-08-24 01:00:00
#
#             storetime   cgid       value  valuenum valueuom warning error  \
# 0 2166-08-24 00:59:00  18941   Full Code       NaN             None  None
# 1 2166-08-24 00:59:00  18941  Occasional       NaN             None  None
# 2 2166-08-24 00:59:00  18941    Frequent       NaN             None  None
# 3 2166-08-24 00:59:00  18941       PAC's       NaN             None  None
# 4 2166-08-24 00:59:00  18941       PVC's       NaN             None  None
#
#   resultstatus   stopped
# 0               NotStopd
# 1               NotStopd
# 2               NotStopd
# 3               NotStopd
# 4               NotStopd

# %% [markdown]
# ### DateTimeEvents Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM datetimeevents;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 4486049 rows and  14 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# icustay_id
# itemid
# charttime
# storetime
# cgid
# value
# valueuom
# warning
# error
# resultstatus
# stopped
#    row_id  subject_id   hadm_id  icustay_id  itemid           charttime  \
# 0       1           6  107064.0    228232.0    5684 2175-05-31 08:00:00
# 1       2           6  107064.0    228232.0    5685 2175-05-31 08:00:00
# 2       3           6  107064.0    228232.0    6703 2175-05-31 08:00:00
# 3       4           6  107064.0    228232.0    6705 2175-05-31 08:00:00
# 4       5           6  107064.0    228232.0    5684 2175-05-31 12:00:00
#
#             storetime   cgid                value valueuom  warning  error  \
# 0 2175-05-31 12:33:00  18765  2175-05-31 00:00:00     Date      NaN    NaN
# 1 2175-05-31 12:33:00  18765  2175-05-31 00:00:00     Date      NaN    NaN
# 2 2175-05-31 12:33:00  18765  2175-05-30 00:00:00     Date      NaN    NaN
# 3 2175-05-31 12:33:00  18765  2175-05-30 00:00:00     Date      NaN    NaN
# 4 2175-05-31 12:33:00  18765  2175-05-31 00:00:00     Date      NaN    NaN
#
#   resultstatus   stopped
# 0               NotStopd
# 1               NotStopd
# 2               NotStopd
# 3               NotStopd
# 4               NotStopd

# %% [markdown]
# ### InputEvents_CV Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM inputevents_cv
LIMIT 100;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 100 rows and  22 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# icustay_id
# charttime
# itemid
# amount
# amountuom
# rate
# rateuom
# storetime
# cgid
# orderid
# linkorderid
# stopped
# newbottle
# originalamount
# originalamountuom
# originalroute
# originalrate
# originalrateuom
# originalsite
#    row_id  subject_id   hadm_id  icustay_id           charttime  itemid  \
# 0      91       19246  150542.0    222823.0 2126-09-12 16:00:00   30056
# 1      92       19246  150542.0    222823.0 2126-09-12 23:00:00   30056
# 2      93       19246  150542.0    222823.0 2126-09-13 09:00:00   30056
# 3      94       19246  150542.0    222823.0 2126-09-13 15:00:00   30056
# 4     189       14469  155925.0    204432.0 2111-06-21 10:00:00   30056
#
#    amount amountuom  rate rateuom     ...        orderid  linkorderid  \
# 0   100.0        ml  None             ...        4856159     11454421
# 1   360.0        ml  None             ...        1410862     11454421
# 2    40.0        ml  None             ...       11265173     11454421
# 3   180.0        ml  None             ...        9115179     11454421
# 4   120.0        ml  None             ...        7890709      3252849
#
#    stopped  newbottle originalamount originalamountuom originalroute  \
# 0                None           None                ml          Oral
# 1                None           None                ml          Oral
# 2                None           None                ml          Oral
# 3                None           None                ml          Oral
# 4                None           None                ml          Oral
#
#   originalrate originalrateuom originalsite
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#
# [5 rows x 22 columns]

# %% [markdown]
# ### InputEvents_MV Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM inputevents_mv
LIMIT 100;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 100 rows and  31 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# icustay_id
# starttime
# endtime
# itemid
# amount
# amountuom
# rate
# rateuom
# storetime
# cgid
# orderid
# linkorderid
# ordercategoryname
# secondaryordercategoryname
# ordercomponenttypedescription
# ordercategorydescription
# patientweight
# totalamount
# totalamountuom
# isopenbag
# continueinnextdept
# cancelreason
# statusdescription
# comments_editedby
# comments_canceledby
# comments_date
# originalamount
# originalrate
#    row_id  subject_id  hadm_id  icustay_id           starttime  \
# 0       1       30354   120396         NaN 2154-12-24 12:00:00
# 1       2       30354   120396         NaN 2154-12-25 08:30:00
# 2       3       30354   120396         NaN 2154-12-24 12:00:00
# 3       4       30354   120396         NaN 2154-12-24 12:00:00
# 4       5       30354   120396         NaN 2154-12-24 15:37:00
#
#               endtime  itemid      amount amountuom       rate      ...       \
# 0 2154-12-24 16:20:00  225828  325.000000        mL  75.000000      ...
# 1 2154-12-25 08:31:00  225799   30.000000        mL        NaN      ...
# 2 2154-12-24 14:00:00  221744    0.000050        mg  25.000000      ...
# 3 2154-12-24 14:00:00  220949    5.000000        mL   2.500000      ...
# 4 2154-12-24 17:00:00  221668    0.005532        mg   3.999322      ...
#
#   totalamountuom isopenbag  continueinnextdept  cancelreason  \
# 0             mL         0                   0             2
# 1             mL         0                   0             0
# 2             mL         0                   0             0
# 3             mL         0                   0             0
# 4             mL         0                   0             0
#
#    statusdescription comments_editedby comments_canceledby  \
# 0          Rewritten                RN
# 1    FinishedRunning
# 2    FinishedRunning
# 3    FinishedRunning
# 4            Changed
#
#         comments_date originalamount  originalrate
# 0 2154-12-24 23:34:00     325.000000          75.0
# 1                 NaT      30.000000          30.0
# 2                 NaT       0.050000          25.0
# 3                 NaT       5.000000           2.5
# 4                 NaT      98.383331           4.0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### NoteEvents Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM noteevents
LIMIT 100;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 100 rows and  11 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# chartdate
# charttime
# storetime
# category
# description
# cgid
# iserror
# text
#    row_id  subject_id  hadm_id  chartdate charttime storetime  \
# 0       1       23224   174680 2147-12-05      None      None
# 1       2       23224   117806 2154-05-03      None      None
# 2       3       19051   184534 2172-04-23      None      None
# 3       4       14605   195146 2198-11-27      None      None
# 4       5        9446   154895 2190-05-22      None      None
#
#             category description  cgid iserror  \
# 0  Discharge summary      Report  None
# 1  Discharge summary      Report  None
# 2  Discharge summary      Report  None
# 3  Discharge summary      Report  None
# 4  Discharge summary      Report  None
#
#                                                 text
# 0  Admission Date:  [**2823-9-29**]              ...
# 1  Admission Date:  [**2830-3-12**]              ...
# 2  Admission Date:  [**2714-3-12**]              ...
# 3  Admission Date:  [**2678-10-4**]              ...
# 4  Admission Date:  [**2936-5-6**]     Discharge ...

# %% [markdown]
# ### OutputEvents Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM outputevents;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 4349339 rows and  13 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# icustay_id
# charttime
# itemid
# value
# valueuom
# storetime
# cgid
# stopped
# newbottle
# iserror
#    row_id  subject_id   hadm_id  icustay_id           charttime  itemid  \
# 0     252       21219  177991.0    225765.0 2142-09-02 16:00:00   40055
# 1     253       21219  177991.0    225765.0 2142-09-02 16:30:00   40055
# 2     254       21219  177991.0    225765.0 2142-09-02 18:00:00   40055
# 3     255       21219  177991.0    225765.0 2142-09-02 20:00:00   40055
# 4     256       21219  177991.0    225765.0 2142-09-02 21:00:00   40055
#
#    value valueuom           storetime   cgid stopped newbottle iserror
# 0  180.0       ml 2142-09-02 16:13:00  18367              None    None
# 1  210.0       ml 2142-09-02 16:42:00  18367              None    None
# 2  180.0       ml 2142-09-02 18:34:00  18367              None    None
# 3  350.0       ml 2142-09-02 20:13:00  14431              None    None
# 4  110.0       ml 2142-09-02 21:19:00  14431              None    None

# %% [markdown]
# ### ProcedureEvents_MV Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM procedureevents_mv;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 258066 rows and  25 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# icustay_id
# starttime
# endtime
# itemid
# value
# valueuom
# location
# locationcategory
# storetime
# cgid
# orderid
# linkorderid
# ordercategoryname
# secondaryordercategoryname
# ordercategorydescription
# isopenbag
# continueinnextdept
# cancelreason
# statusdescription
# comments_editedby
# comments_canceledby
# comments_date
#    row_id  subject_id  hadm_id  icustay_id           starttime  \
# 0       1       30354   120396         NaN 2154-12-24 12:00:00
# 1       2       30354   120396         NaN 2154-12-24 12:00:00
# 2       3       30354   120396         NaN 2154-12-24 12:03:00
# 3       4       30354   120396         NaN 2154-12-24 12:06:00
# 4       5       30354   120396         NaN 2154-12-24 15:49:00
#
#               endtime  itemid   value valueuom        location      ...        \
# 0 2154-12-25 17:02:00  224274  1742.0      min          L Hand      ...
# 1 2154-12-26 13:00:00  224275  2940.0      min  LL Ant Forearm      ...
# 2 2154-12-24 12:04:00  224385     1.0     None                      ...
# 3 2154-12-26 17:00:00  225792  3174.0      min                      ...
# 4 2154-12-24 15:50:00  226237     1.0     None                      ...
#
#        ordercategoryname secondaryordercategoryname  ordercategorydescription  \
# 0       Peripheral Lines                                                 Task
# 1       Peripheral Lines                                                 Task
# 2  Intubation/Extubation                                         Electrolytes
# 3            Ventilation                                                 Task
# 4             Procedures                                         Electrolytes
#
#    isopenbag  continueinnextdept cancelreason statusdescription  \
# 0          1                   0            0   FinishedRunning
# 1          1                   0            0   FinishedRunning
# 2          0                   0            0   FinishedRunning
# 3          1                   0            0   FinishedRunning
# 4          0                   0            0   FinishedRunning
#
#   comments_editedby  comments_canceledby  comments_date
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Hospital Record Tables

# %% [markdown]
# ### CPTEvents Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM cptevents;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 573146 rows and  12 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# costcenter
# chartdate
# cpt_cd
# cpt_number
# cpt_suffix
# ticket_id_seq
# sectionheader
# subsectionheader
# description
#    row_id  subject_id  hadm_id costcenter chartdate cpt_cd  cpt_number  \
# 0     160         482   145066        ICU      None  99233     99233.0
# 1     161         482   145066        ICU      None  99232     99232.0
# 2     162         482   145066        ICU      None  99232     99232.0
# 3     163         482   145066        ICU      None  99232     99232.0
# 4     164         482   145066        ICU      None  99232     99232.0
#
#   cpt_suffix  ticket_id_seq              sectionheader  \
# 0                       1.0  Evaluation and management
# 1                       2.0  Evaluation and management
# 2                       3.0  Evaluation and management
# 3                       4.0  Evaluation and management
# 4                       5.0  Evaluation and management
#
#               subsectionheader description
# 0  Hospital inpatient services
# 1  Hospital inpatient services
# 2  Hospital inpatient services
# 3  Hospital inpatient services
# 4  Hospital inpatient services

# %% [markdown]
# ### Diagnoses_ICD Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM diagnoses_icd;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 651047 rows and  5 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# seq_num
# icd9_code
#    row_id  subject_id  hadm_id  seq_num icd9_code
# 0     243          34   115799      8.0     E8790
# 1     244          34   144319      1.0     42789
# 2     245          34   144319      2.0     42822
# 3     246          34   144319      3.0      4263
# 4     247          34   144319      4.0     41401

# %% [markdown]
# ### DRGCodes Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM drgcodes;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 125557 rows and  8 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# drg_type
# drg_code
# description
# drg_severity
# drg_mortality
#    row_id  subject_id  hadm_id drg_type drg_code  \
# 0       1       78996   138854     HCFA      107
# 1       2       25080   185945     HCFA      104
# 2       3       11677   137776     HCFA      202
# 3       4       20409   102314     HCFA      483
# 4       5       11705   165730     HCFA      390
#
#                                          description  drg_severity  \
# 0              CORONARY BYPASS WITH CARDIAC CATHETER           NaN
# 1  CARDIAC VALVE & OTHER MAJOR CARDIOTHORACIC PRO...           NaN
# 2                    CIRRHOSIS & ALCOHOLIC HEPATITIS           NaN
# 3  TRACHEOSTOMY EXCEPT FOR FACE, MOUTH, & NECK DI...           NaN
# 4            NEONATE WITH OTHER SIGNIFICANT PROBLEMS           NaN
#
#    drg_mortality
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %% [markdown]
# ### LabEvents Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM labevents
LIMIT 100;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 100 rows and  9 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# itemid
# charttime
# value
# valuenum
# valueuom
# flag
#    row_id  subject_id  hadm_id  itemid           charttime value  valuenum  \
# 0     281           3      NaN   50820 2101-10-12 17:07:00  7.39      7.39
# 1     282           3      NaN   50800 2101-10-12 19:17:00   ART       NaN
# 2     283           3      NaN   50802 2101-10-12 19:17:00    -1     -1.00
# 3     284           3      NaN   50804 2101-10-12 19:17:00    22     22.00
# 4     285           3      NaN   50808 2101-10-12 19:17:00  0.93      0.93
#
#   valueuom      flag
# 0    units
# 1
# 2    mEq/L
# 3    mEq/L
# 4   mmol/L  abnormal

# %% [markdown]
# ### MicroBiologyEvents Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM microbiologyevents;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 328446 rows and  16 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# chartdate
# charttime
# spec_itemid
# spec_type_desc
# org_itemid
# org_name
# isolate_num
# ab_itemid
# ab_name
# dilution_text
# dilution_comparison
# dilution_value
# interpretation
#    row_id  subject_id   hadm_id  chartdate charttime  spec_itemid  \
# 0     130        5282  132174.0 2109-08-05      None      70079.0
# 1     131        5282  132174.0 2109-08-05      None      70079.0
# 2     132        5282  132174.0 2109-08-05      None      70079.0
# 3     133        5282  132174.0 2109-08-05      None      70079.0
# 4     134        5282  132174.0 2109-08-05      None      70079.0
#
#   spec_type_desc  org_itemid              org_name  isolate_num  ab_itemid  \
# 0          URINE     80019.0  PROVIDENCIA STUARTII            1    90026.0
# 1          URINE     80019.0  PROVIDENCIA STUARTII            1    90013.0
# 2          URINE     80019.0  PROVIDENCIA STUARTII            1    90029.0
# 3          URINE     80019.0  PROVIDENCIA STUARTII            1    90028.0
# 4          URINE     80019.0  PROVIDENCIA STUARTII            1    90019.0
#
#              ab_name dilution_text dilution_comparison  dilution_value  \
# 0  PIPERACILLIN/TAZO            64                   =            64.0
# 1         TOBRAMYCIN          =>16                  =>            16.0
# 2          MEROPENEM        <=0.25                  <=             0.0
# 3           CEFEPIME             2                   =             2.0
# 4      CIPROFLOXACIN           =>4                  =>             4.0
#
#   interpretation
# 0              I
# 1              R
# 2              S
# 3              S
# 4              R

# %% [markdown]
# ### Prescriptions Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM prescriptions
LIMIT 100;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 100 rows and  19 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# icustay_id
# startdate
# enddate
# drug_type
# drug
# drug_name_poe
# drug_name_generic
# formulary_drug_cd
# gsn
# ndc
# prod_strength
# dose_val_rx
# dose_unit_rx
# form_val_disp
# form_unit_disp
# route
#    row_id  subject_id  hadm_id  icustay_id  startdate    enddate drug_type  \
# 0      59       57139   155470    276227.0 2185-12-26 2185-12-30      MAIN
# 1      60       57139   155470    276227.0 2185-12-26 2185-12-27      MAIN
# 2      61       57139   155470    276227.0 2185-12-26 2185-12-31      MAIN
# 3      62       57139   155470    276227.0 2185-12-27 2185-12-27      MAIN
# 4      63       57139   155470    276227.0 2185-12-27 2185-12-27      MAIN
#
#                 drug      drug_name_poe        drug_name_generic  \
# 0           Propofol           Propofol                 Propofol
# 1            Heparin            Heparin           Heparin Sodium
# 2            Insulin            Insulin  Insulin - Sliding Scale
# 3         Furosemide         Furosemide               Furosemide
# 4  Magnesium Sulfate  Magnesium Sulfate        Magnesium Sulfate
#
#   formulary_drug_cd     gsn          ndc                    prod_strength  \
# 0         PROP200IG  016796  63323026920                  200mg/20mL Vial
# 1            HEPA5I  006549  63323026201        5000 Units / mL- 1mL Vial
# 2           INSULIN  027413            0  Dummy Package for Sliding Scale
# 3           FURO40I  008205  00517570425                    40mg/4mL Vial
# 4            MAG2PM  016546  00409672924           2 g / 50 mL Premix Bag
#
#   dose_val_rx dose_unit_rx form_val_disp form_unit_disp    route
# 0         200           mg             1           VIAL  IV DRIP
# 1        5000         UNIT             1             mL       SC
# 2           0         UNIT             0           VIAL       SC
# 3          20           mg           0.5           VIAL       IV
# 4           2           gm             1            BAG       IV

# %% [markdown]
# ### Procedures_ICD Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM procedures_icd;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 240095 rows and  5 columns
#
# Column Names:
# row_id
# subject_id
# hadm_id
# seq_num
# icd9_code
#    row_id  subject_id  hadm_id  seq_num icd9_code
# 0     397        5259   195496        7       966
# 1     398       89817   145376        1      3812
# 2     399        5617   164900        1      8005
# 3     400        5617   164900        2      8191
# 4     401        5617   164900        3      3893

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# ### D_CPT

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM d_cpt;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 134 rows and  9 columns
#
# Column Names:
# row_id
# category
# sectionrange
# sectionheader
# subsectionrange
# subsectionheader
# codesuffix
# mincodeinsubsection
# maxcodeinsubsection
#    row_id  category sectionrange              sectionheader subsectionrange  \
# 0       1         1  99201-99499  Evaluation and management     99201-99216
# 1       2         1  99201-99499  Evaluation and management     99217-99220
# 2       3         1  99201-99499  Evaluation and management     99221-99239
# 3       4         1  99201-99499  Evaluation and management     99241-99255
# 4       5         1  99201-99499  Evaluation and management     99261-99263
#
#                                     subsectionheader codesuffix  \
# 0                   Office/other outpatient services
# 1                      Hospital observation services
# 2                        Hospital inpatient services
# 3                                      Consultations
# 4  Follow-up inpatient consultations (deleted codes)
#
#    mincodeinsubsection  maxcodeinsubsection
# 0                99201                99216
# 1                99217                99220
# 2                99221                99239
# 3                99241                99255
# 4                99261                99263

# %% [markdown]
# ### D_ICD_Diagnoses Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM d_icd_diagnoses;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 14567 rows and  4 columns
#
# Column Names:
# row_id
# icd9_code
# short_title
# long_title
#    row_id icd9_code             short_title                       long_title
# 0      55      0065    Amebic brain abscess             Amebic brain abscess
# 1      56      0066  Amebic skin ulceration           Amebic skin ulceration
# 2      57      0068    Amebic infection NEC  Amebic infection of other sites
# 3      58      0069           Amebiasis NOS           Amebiasis, unspecified
# 4      59      0070           Balantidiasis                    Balantidiasis

# %% [markdown]
# ### D_ICD_Procedures Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM d_icd_procedures;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 3882 rows and  4 columns
#
# Column Names:
# row_id
# icd9_code
# short_title
# long_title
#    row_id icd9_code               short_title  \
# 0      86      0064  Perc ins extracran stent
# 1      87      0065  Perc ins intracran stent
# 2      88      0066                      PTCA
# 3      89      0067  Intravas msmnt thorc art
# 4      90      0068  Intravas msmt periph art
#
#                                           long_title
# 0  Percutaneous insertion of other extracranial a...
# 1  Percutaneous insertion of intracranial vascula...
# 2  Percutaneous transluminal coronary angioplasty...
# 3  Intravascular pressure measurement of intratho...
# 4  Intravascular pressure measurement of peripher...

# %% [markdown]
# ### D_Items Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM d_items;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data.head()
# Out:
# Table Dimensions: 12478 rows and  10 columns
#
# Column Names:
# row_id
# itemid
# label
# abbreviation
# dbsource
# linksto
# category
# unitname
# param_type
# conceptid
#    row_id  itemid                 label abbreviation dbsource      linksto  \
# 0     262     264  INV Line#7 Site Date               carevue  chartevents
# 1     263     265     INV Line#7 [Type]               carevue  chartevents
# 2     264     266   INV Line#7 Zero/Cal               carevue  chartevents
# 3     265     267  INV Line#7InsertDate               carevue  chartevents
# 4     266     268  INV Line#7SiteAppear               carevue  chartevents
#
#   category unitname param_type conceptid
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None

# %% [markdown]
# ### D_LabItems Table

# %%
cur.execute('SET search_path to ' + schema_name)
query = \
"""
SELECT *
FROM d_labitems AS d
WHERE fluid = 'BLOOD'
ORDER BY label;
"""
data = pd.read_sql_query(query,con)

print "Table Dimensions:", data.shape[0], "rows and ", data.shape[1], "columns"

print "\nColumn Names:"
for col in data.columns:
    print col
    
data
# Out:
# Table Dimensions: 376 rows and  6 columns
#
# Column Names:
# row_id
# itemid
# label
# fluid
# category
# loinc_code
#      row_id  itemid                            label  fluid    category  \
# 0        53   50852                 % HEMOGLOBIN A1C  BLOOD   CHEMISTRY
# 1        54   50853                  25-OH VITAMIN D  BLOOD   CHEMISTRY
# 2        55   50854                     ABSOLUTE A1C  BLOOD   CHEMISTRY
# 3       330   51130               ABSOLUTE CD3 COUNT  BLOOD  HEMATOLOGY
# 4       331   51131               ABSOLUTE CD4 COUNT  BLOOD  HEMATOLOGY
# 5       332   51132               ABSOLUTE CD8 COUNT  BLOOD  HEMATOLOGY
# 6        56   50855              ABSOLUTE HEMOGLOBIN  BLOOD   CHEMISTRY
# 7       333   51133        ABSOLUTE LYMPHOCYTE COUNT  BLOOD  HEMATOLOGY
# 8       334   51134                     ACANTHOCYTES  BLOOD  HEMATOLOGY
# 9        57   50856                    ACETAMINOPHEN  BLOOD   CHEMISTRY
# 10       58   50857                          ACETONE  BLOOD   CHEMISTRY
# 11      721   51521                        ACID PHOS  BLOOD   CHEMISTRY
# 12       59   50858                 ACID PHOSPHATASE  BLOOD   CHEMISTRY
# 13       60   50859  ACID PHOSPHATASE, NON-PROSTATIC  BLOOD   CHEMISTRY
# 14      335   51135                              ADP  BLOOD  HEMATOLOGY
# 15       61   50860             AFP, MATERNAL SCREEN  BLOOD   CHEMISTRY
# 16       62   50861   ALANINE AMINOTRANSFERASE (ALT)  BLOOD   CHEMISTRY
# 17       63   50862                          ALBUMIN  BLOOD   CHEMISTRY
# 18       64   50863             ALKALINE PHOSPHATASE  BLOOD   CHEMISTRY
# 19      336   51136                ALPHA ANTIPLASMIN  BLOOD  HEMATOLOGY
# 20       65   50864                ALPHA-FETOPROTEIN  BLOOD   CHEMISTRY
# 21        2   50801       ALVEOLAR-ARTERIAL GRADIENT  BLOOD   BLOOD GAS
# 22       66   50865                         AMIKACIN  BLOOD   CHEMISTRY
# 23       67   50866                          AMMONIA  BLOOD   CHEMISTRY
# 24       68   50867                          AMYLASE  BLOOD   CHEMISTRY
# 25       69   50868                        ANION GAP  BLOOD   CHEMISTRY
# 26      337   51137                     ANISOCYTOSIS  BLOOD  HEMATOLOGY
# 27       70   50869               ANTI-DGP (IGA/IGG)  BLOOD   CHEMISTRY
# 28       71   50870       ANTI-GLIADIN ANTIBODY, IGA  BLOOD   CHEMISTRY
# 29      720   51520                          ANTI-MC  BLOOD   CHEMISTRY
# ..      ...     ...                              ...    ...         ...
# 346     195   50995             THYROXINE (T4), FREE  BLOOD   CHEMISTRY
# 347      27   50826                     TIDAL VOLUME  BLOOD   BLOOD GAS
# 348     196   50996  TISSUE TRANSGLUTAMINASE AB, IGA  BLOOD   CHEMISTRY
# 349     197   50997                       TOBRAMYCIN  BLOOD   CHEMISTRY
# 350     198   50998                      TRANSFERRIN  BLOOD   CHEMISTRY
# 351     199   50999  TRICYCLIC ANTIDEPRESSANT SCREEN  BLOOD   CHEMISTRY
# 352     200   51000                    TRIGLYCERIDES  BLOOD   CHEMISTRY
# 353     201   51001            TRIIODOTHYRONINE (T3)  BLOOD   CHEMISTRY
# 354     202   51002                       TROPONIN I  BLOOD   CHEMISTRY
# 355     203   51003                       TROPONIN T  BLOOD   CHEMISTRY
# 356     204   51004             UE3, MATERNAL SCREEN  BLOOD   CHEMISTRY
# 357     205   51005                     UPTAKE RATIO  BLOOD   CHEMISTRY
# 358     206   51006                    UREA NITROGEN  BLOOD   CHEMISTRY
# 359     207   51007                        URIC ACID  BLOOD   CHEMISTRY
# 360     208   51008                    VALPROIC ACID  BLOOD   CHEMISTRY
# 361     209   51009                       VANCOMYCIN  BLOOD   CHEMISTRY
# 362      28   50827                 VENTILATION RATE  BLOOD   BLOOD GAS
# 363      29   50828                       VENTILATOR  BLOOD   BLOOD GAS
# 364     210   51010                      VITAMIN B12  BLOOD   CHEMISTRY
# 365     745   51545                  VOIDED SPECIMEN  BLOOD   BLOOD GAS
# 366     750   51550                  VOIDED SPECIMEN  BLOOD  HEMATOLOGY
# 367     743   51543                  VOIDED SPECIMEN  BLOOD   CHEMISTRY
# 368     498   51298   VON WILLEBRAND FACTOR ACTIVITY  BLOOD  HEMATOLOGY
# 369     499   51299    VON WILLEBRAND FACTOR ANTIGEN  BLOOD  HEMATOLOGY
# 370     500   51300                        WBC COUNT  BLOOD  HEMATOLOGY
# 371     733   51533                             WBCP  BLOOD  HEMATOLOGY
# 372     501   51301                WHITE BLOOD CELLS  BLOOD  HEMATOLOGY
# 373     502   51302                      YOUNG CELLS  BLOOD  HEMATOLOGY
# 374     738   51538                            [A1c]  BLOOD   CHEMISTRY
# 375     729   51529                              eAG  BLOOD   CHEMISTRY
#
#     loinc_code
# 0       4548-4
# 1
# 2       4548-4
# 3       8124-0
# 4       8128-1
# 5       8138-0
# 6        718-7
# 7      26474-7
# 8       7789-1
# 9       3297-9
# 10      5567-3
# 11      1711-1
# 12      1715-2
# 13
# 14
# 15
# 16      1742-6
# 17      1751-7
# 18      6768-6
# 19
# 20      1834-1
# 21     19991-9
# 22
# 23     16362-6
# 24      1798-8
# 25      1863-0
# 26       702-1
# 27
# 28      7893-1
# 29     32042-4
# ..         ...
# 346     3024-7
# 347    20112-9
# 348    31017-7
# 349    35670-9
# 350     2500-7
# 351     4073-3
# 352     1644-4
# 353     3053-6
# 354    10839-9
# 355     6598-7
# 356
# 357     3050-2
# 358     3094-0
# 359     3084-1
# 360     4086-5
# 361    20578-1
# 362
# 363
# 364     2170-9
# 365
# 366
# 367
# 368     6014-5
# 369     6012-9
# 370    26464-8
# 371
# 372      804-5
# 373    51633-6
# 374     4548-4
# 375
#
# [376 rows x 6 columns]

# %%
for label in data.label:
    print label
# Out:
# % HEMOGLOBIN A1C
# 25-OH VITAMIN D
# ABSOLUTE A1C
# ABSOLUTE CD3 COUNT
# ABSOLUTE CD4 COUNT
# ABSOLUTE CD8 COUNT
# ABSOLUTE HEMOGLOBIN
# ABSOLUTE LYMPHOCYTE COUNT
# ACANTHOCYTES
# ACETAMINOPHEN
# ACETONE
# ACID PHOS
# ACID PHOSPHATASE
# ACID PHOSPHATASE, NON-PROSTATIC
# ADP
# AFP, MATERNAL SCREEN
# ALANINE AMINOTRANSFERASE (ALT)
# ALBUMIN
# ALKALINE PHOSPHATASE
# ALPHA ANTIPLASMIN
# ALPHA-FETOPROTEIN
# ALVEOLAR-ARTERIAL GRADIENT
# AMIKACIN
# AMMONIA
# AMYLASE
# ANION GAP
# ANISOCYTOSIS
# ANTI-DGP (IGA/IGG)
# ANTI-GLIADIN ANTIBODY, IGA
# ANTI-MC
# ANTI-MITOCHONDRIAL ANTIBODY
# ANTI-NEUTROPHIL CYTOPLASMIC ANTIBODY
# ANTI-NUCLEAR ANTIBODY
# ANTI-NUCLEAR ANTIBODY, TITER
# ANTI-PARIETAL CELL ANTIBODY
# ANTI-SMOOTH MUSCLE ANTIBODY
# ANTI-THYROGLOBULIN ANTIBODIES
# ANTICARDIOLIPIN ANTIBODY IGG
# ANTICARDIOLIPIN ANTIBODY IGM
# ANTITHROMBIN
# APT TEST
# ARACHADONIC ACID
# ASPARATE AMINOTRANSFERASE (AST)
# ATYPICAL LYMPHOCYTES
# BANDS
# BARBITURATE SCREEN
# BASE EXCESS
# BASOPHILIC STIPPLING
# BASOPHILS
# BENZODIAZEPINE SCREEN
# BETA-2 MICROGLOBULIN
# BICARBONATE
# BILIRUBIN, DIRECT
# BILIRUBIN, INDIRECT
# BILIRUBIN, TOTAL
# BITE CELLS
# BLASTS
# BLEEDING TIME
# BLOOD CULTURE HOLD
# BLOOD PARASITE SMEAR
# BLUE TOP HOLD
# BLUE TOP HOLD FROZEN
# BURR CELLS
# Billed
# C-REACTIVE PROTEIN
# C3
# C4
# CA-125
# CALCIUM, TOTAL
# CALCULATED BICARBONATE, WHOLE BLOOD
# CALCULATED FREE TESTOSTERONE
# CALCULATED TBG
# CALCULATED THYROXINE (T4) INDEX
# CALCULATED TOTAL CO2
# CALL
# CANCER ANTIGEN 27.29
# CARBAMAZEPINE
# CARBOXYHEMOGLOBIN
# CARCINOEMBYRONIC ANTIGEN (CEA)
# CD10
# CD103
# CD117
# CD11C
# CD13
# CD138
# CD14
# CD15
# CD15/56
# CD16
# CD16/56 ABSOLUTE COUNT
# CD16/56%
# CD19
# CD19 %
# CD19 ABSOLUTE COUNT
# CD2
# CD20
# CD20 %
# CD20 ABSOLUTE COUNT
# CD22
# CD23
# CD25
# CD3 %
# CD3 ABSOLUTE COUNT
# CD3 CELLS, PERCENT
# CD33
# CD34
# CD38
# CD4 CELLS, PERCENT
# CD4/CD8 RATIO
# CD41
# CD45
# CD5
# CD5 %
# CD5 ABSOLUTE COUNT
# CD55
# CD56
# CD57
# CD59
# CD64
# CD7
# CD71
# CD8 CELLS, PERCENT
# CENTROMERE
# CHLORIDE
# CHLORIDE, WHOLE BLOOD
# CHOLESTEROL RATIO (TOTAL/HDL)
# CHOLESTEROL, HDL
# CHOLESTEROL, LDL, CALCULATED
# CHOLESTEROL, LDL, MEASURED
# CHOLESTEROL, TOTAL
# CK-MB INDEX
# COLLAGEN
# COMMENTS
# CORTISOL
# CREATINE KINASE (CK)
# CREATINE KINASE, MB ISOENZYME
# CREATININE
# CRYOGLOBULIN
# CYCLOSPORIN
# D-DIMER
# D-DIMER
# DHEA-SULFATE
# DIGOXIN
# DOUBLE STRANDED DNA
# EDTA HOLD
# ELLIPTOCYTES
# ENVELOPE CELLS
# EOSINOPHIL COUNT
# EOSINOPHILS
# EPINEPHERINE
# ESTIMATED GFR (MDRD EQUATION)
# ESTRADIOL
# ETHANOL
# FACTOR II
# FACTOR IX
# FACTOR V
# FACTOR VII
# FACTOR VIII
# FACTOR VIII INHIBITOR
# FACTOR X
# FACTOR XI
# FACTOR XII
# FACTOR XIII
# FAX
# FERRITIN
# FETAL HEMOGLOBIN
# FIBRIN DEGRADATION PRODUCTS
# FIBRINOGEN, FUNCTIONAL
# FMC-7
# FOLATE
# FOLLICLE STIMULATING HORMONE
# FRAGMENTED CELLS
# FREE CALCIUM
# FRUCAMN+
# GAMMA GLUTAMYLTRANSFERASE
# GASTRIN
# GENTAMICIN
# GLOBULIN
# GLUCOSE
# GLUCOSE
# GLYCO A
# GRANULOCYTE COUNT
# GRAY TOP HOLD (PLASMA)
# GREEN TOP HOLD (PLASMA)
# H
# H/O SMEAR
# HAPTOGLOBIN
# HCG, MATERNAL SCREEN
# HEINZ BODY PREP
# HEMATOCRIT
# HEMATOCRIT, CALCULATED
# HEMOGLOBIN
# HEMOGLOBIN
# HEMOGLOBIN A2
# HEMOGLOBIN C
# HEMOGLOBIN F
# HEMOGLOBLIN A
# HEMOGLOBLIN S
# HEPARIN
# HEPARIN, LMW
# HEPATITIS A VIRUS ANTIBODY
# HEPATITIS A VIRUS IGM ANTIBODY
# HEPATITIS B CORE ANTIBODY, IGM
# HEPATITIS B SURFACE ANTIBODY
# HEPATITIS B SURFACE ANTIGEN
# HEPATITIS B VIRUS CORE ANTIBODY
# HEPATITIS C VIRUS ANTIBODY
# HIV ANTIBODY
# HLA-DR
# HOMOCYSTEINE
# HOWELL-JOLLY BODIES
# HUMAN CHORIONIC GONADOTROPIN
# HYPERSEGMENTED NEUTROPHILS
# HYPOCHROMIA
# I
# IMMUNOFIXATION
# IMMUNOGLOBULIN A
# IMMUNOGLOBULIN G
# IMMUNOGLOBULIN M
# IMMUNOPHENOTYPING
# INHIBITOR SCREEN
# INPATIENT HEMATOLOGY/ONCOLOGY SMEAR
# INR(PT)
# INTUBATED
# IRON
# IRON BINDING CAPACITY, TOTAL
# KAPPA
# LACTATE
# LACTATE DEHYDROGENASE (LD)
# LAMBDA
# LARGE PLATELETS
# LEUKOCYTE ALKALINE PHOSPHATASE
# LIGHT GREEN TOP HOLD
# LIPASE
# LITHIUM
# LUC
# LUPUS ANTICOAGULANT
# LUTEINIZING HORMONE
# LYMPHOCYTES
# LYMPHOCYTES, PERCENT
# MACRO PROLACTIN
# MACROCYTES
# MACROOVALOCYTES
# MAGNESIUM
# MCH
# MCHC
# MCV
# METAMYELOCYTES
# METHEMOGLOBIN
# METHOTREXATE
# MICROCYTES
# MONOCYTE COUNT
# MONOCYTES
# MS-DIA
# MYELOCYTES
# N-ACETYLPROCAINAMIDE (NAPA)
# NEUTROPHILS
# NTPROBNP
# NUCLEATED RED CELLS
# O2 FLOW
# OSMOLALITY, MEASURED
# OSMOTIC FRAGILITY
# OTHER CELLS
# OVALOCYTES
# OXYGEN
# OXYGEN SATURATION
# PAPPENHEIMER BODIES
# PARATHYROID HORMONE
# PCO2
# PEEP
# PENCIL CELLS
# PH
# PHENOBARBITAL
# PHENYTOIN
# PHENYTOIN, FREE
# PHENYTOIN, PERCENT FREE
# PHOSPHATE
# PLASMA CELLS
# PLASMGN
# PLATELET CLUMPS
# PLATELET COUNT
# PLATELET SMEAR
# PO2
# POIKILOCYTOSIS
# POLYCHROMASIA
# POTASSIUM
# POTASSIUM, WHOLE BLOOD
# PROBLEM SPECIMEN
# PROBLEM SPECIMEN
# PROCAINAMIDE
# PROLACTIN
# PROMYELOCYTES
# PROSTATE SPECIFIC ANTIGEN
# PROTEIN C, ANTIGEN
# PROTEIN C, FUNCTIONAL
# PROTEIN ELECTROPHORESIS
# PROTEIN S, ANTIGEN
# PROTEIN S, FUNCTIONAL
# PROTEIN, TOTAL
# PT
# PTT
# QUANTITATIVE G6PD
# QUINIDINE
# RAPAMYCIN
# RDW
# RED BLOOD CELL FRAGMENTS
# RED BLOOD CELLS
# RED TOP HOLD
# REPTILASE TIME
# REPTILASE TIME CONTROL
# REQUIRED O2
# RETICULOCYTE COUNT, ABSOLUTE
# RETICULOCYTE COUNT, AUTOMATED
# RETICULOCYTE COUNT, MANUAL
# RETICULOCYTE, CELLULAR HEMOGLOBIN
# RHEUMATOID FACTOR
# RISTOCETIN
# SALICYLATE
# SCHISTOCYTES
# SEDIMENTATION RATE
# SERUM VISCOSITY
# SEX HORMONE BINDING GLOBULIN
# SICKLE CELL PREPARATION
# SICKLE CELLS
# SODIUM
# SODIUM, WHOLE BLOOD
# SPECIMEN TYPE
# SPHEROCYTES
# STAT
# STDY HOLD
# STUDY TUBES
# SUGAR WATER TEST
# TACROFK
# TACROFK_2
# TARGET CELLS
# TDT
# TEARDROP CELLS
# TEMPERATURE
# TESTOSTERONE
# TESTOSTERONE, FREE
# THEOPHYLLINE
# THROMBIN
# THYROGLOBULIN
# THYROID PEROXIDASE ANTIBODIES
# THYROID STIMULATING HORMONE
# THYROXINE (T4)
# THYROXINE (T4), FREE
# TIDAL VOLUME
# TISSUE TRANSGLUTAMINASE AB, IGA
# TOBRAMYCIN
# TRANSFERRIN
# TRICYCLIC ANTIDEPRESSANT SCREEN
# TRIGLYCERIDES
# TRIIODOTHYRONINE (T3)
# TROPONIN I
# TROPONIN T
# UE3, MATERNAL SCREEN
# UPTAKE RATIO
# UREA NITROGEN
# URIC ACID
# VALPROIC ACID
# VANCOMYCIN
# VENTILATION RATE
# VENTILATOR
# VITAMIN B12
# VOIDED SPECIMEN
# VOIDED SPECIMEN
# VOIDED SPECIMEN
# VON WILLEBRAND FACTOR ACTIVITY
# VON WILLEBRAND FACTOR ANTIGEN
# WBC COUNT
# WBCP
# WHITE BLOOD CELLS
# YOUNG CELLS
# [A1c]
# eAG
